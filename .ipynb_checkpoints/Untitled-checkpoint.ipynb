# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

us_names = "./Bus_Routes.csv"

df = pd.read_csv(us_names)

# %%
df.describe()
# Out:
#         OBJECTID  Shape__Length
# count  66.000000      66.000000
# mean   33.500000       0.210691
# std    19.196354       0.086474
# min     1.000000       0.020127
# 25%    17.250000       0.159431
# 50%    33.500000       0.207957
# 75%    49.750000       0.244471
# max    66.000000       0.508037
