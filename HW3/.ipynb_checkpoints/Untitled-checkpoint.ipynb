# %%
import spark
df = spark.read.format("csv").option("header", "true").load("Fiscal_Year_2023_Budget.csv")
# Out:
#   Cell In[5], line 2
#     df = spark.read.format("csv").option("header", "true").load("C:\Users\mpwel\Downloads\Fiscal_Year_2023_Budget.csv")
#                                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
