# %%
import pyspark
df = pyspark.read.format("csv").option("header", "true").load("Fiscal_Year_2023_Budget.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pyspark
#       2 df = pyspark.read.format("csv").option("header", "true").load("Fiscal_Year_2023_Budget.csv")
#
# ModuleNotFoundError: No module named 'pyspark'
